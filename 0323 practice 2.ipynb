# %% [markdown]
# Date -> Month / Hour

# %%
import pandas as pd
df = pd.read_csv("C:/Users/Summer/Desktop/x/Taipei.csv")

# %%
df
# Out:
#                       Date       Page_Name           Page_ID  Link    Type  \
# 0      2020/01/11 23:48:08        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 1      2020/01/12 14:28:57        壯闊台灣 吳怡農  1604793293120494   NaN   video
# 2      2019/08/01 13:43:51  林昶佐 Freddy Lim   365320250345879   NaN   photo
# 3      2020/01/17 20:51:35        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 4      2020/01/11 20:57:56             高嘉瑜      202188887719   NaN   photo
# ...                    ...             ...               ...   ...     ...
# 10238  2019/03/03 11:47:11         立法委員林奕華      209010448523   NaN    link
# 10239  2019/08/12 18:04:21         立法委員林奕華      209010448523   NaN   photo
# 10240  2019/08/24 16:10:18             李彥秀   606321216096498   NaN  status
# 10241  2019/12/18 11:25:11             賴士葆  1573873889493647   NaN   photo
# 10242  2019/12/31 03:47:38       費鴻泰（阿力克司）   893657620668012   NaN    link
#
# ...

# %%
df['Date'].str.split("/")
# Out:
# 0        [2020, 01, 11 23:48:08]
# 1        [2020, 01, 12 14:28:57]
# 2        [2019, 08, 01 13:43:51]
# 3        [2020, 01, 17 20:51:35]
# 4        [2020, 01, 11 20:57:56]
#                   ...
# 10238    [2019, 03, 03 11:47:11]
# 10239    [2019, 08, 12 18:04:21]
# 10240    [2019, 08, 24 16:10:18]
# 10241    [2019, 12, 18 11:25:11]
# 10242    [2019, 12, 31 03:47:38]
# Name: Date, Length: 10243, dtype: object

# %%
df['Date'].str.split(":")
# Out:
# 0        [2020/01/11 23, 48, 08]
# 1        [2020/01/12 14, 28, 57]
# 2        [2019/08/01 13, 43, 51]
# 3        [2020/01/17 20, 51, 35]
# 4        [2020/01/11 20, 57, 56]
#                   ...
# 10238    [2019/03/03 11, 47, 11]
# 10239    [2019/08/12 18, 04, 21]
# 10240    [2019/08/24 16, 10, 18]
# 10241    [2019/12/18 11, 25, 11]
# 10242    [2019/12/31 03, 47, 38]
# Name: Date, Length: 10243, dtype: object

# %%
df["Month"] = df["Date"].str.split(" ").str.get(0).str.title().str.split("/").str.get(1)

# %%
df['Month']
# Out:
# 0        01
# 1        01
# 2        08
# 3        01
# 4        01
#          ..
# 10238    03
# 10239    08
# 10240    08
# 10241    12
# 10242    12
# Name: Month, Length: 10243, dtype: object

# %%
df["Hour"] = df["Date"].str.split(" ").str.get(1).str.title().str.split(":").str.get(0)
df["Hour"]
# Out:
# 0        23
# 1        14
# 2        13
# 3        20
# 4        20
#          ..
# 10238    11
# 10239    18
# 10240    16
# 10241    11
# 10242    03
# Name: Hour, Length: 10243, dtype: object

# %%
df
# Out:
#                       Date       Page_Name           Page_ID  Link    Type  \
# 0      2020/01/11 23:48:08        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 1      2020/01/12 14:28:57        壯闊台灣 吳怡農  1604793293120494   NaN   video
# 2      2019/08/01 13:43:51  林昶佐 Freddy Lim   365320250345879   NaN   photo
# 3      2020/01/17 20:51:35        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 4      2020/01/11 20:57:56             高嘉瑜      202188887719   NaN   photo
# ...                    ...             ...               ...   ...     ...
# 10238  2019/03/03 11:47:11         立法委員林奕華      209010448523   NaN    link
# 10239  2019/08/12 18:04:21         立法委員林奕華      209010448523   NaN   photo
# 10240  2019/08/24 16:10:18             李彥秀   606321216096498   NaN  status
# 10241  2019/12/18 11:25:11             賴士葆  1573873889493647   NaN   photo
# 10242  2019/12/31 03:47:38       費鴻泰（阿力克司）   893657620668012   NaN    link
#
# ...

# %% [markdown]
# 找出 All_Reaction_Count數最少的文章內容

# %%
import pandas as pd
df2 = pd.read_csv("C:/Users/Summer/Desktop/x/Taipei.csv")
print(min(df2.All_Reaction_Count))
# Out:
# 0

# %%
least = df2[(df2['All_Reaction_Count'] == min(df2.All_Reaction_Count) )]['Message']
print(least)
# Out:
# 10225                                       一早來環南市場跟大家說聲早！
# 10226                                                  NaN
# 10227                                                  NaN
# 10228                                                  NaN
# 10229                                                  NaN
# 10230                                                  NaN
# 10231                                                  NaN
# 10232    https://www.facebook.com/136845026417486/posts...
# 10233    柯文哲從藍綠光譜之中，縱切出一塊白色力量。\n但韓國瑜是在既得利益與平民百姓中橫切一刀，用基...
# 10234    【明天開始，做伙來看公視台語台！】\n\n明仔載「公視台語台」就欲開播啊！以後米魯就有閣較齊...
# 10235                                           感謝 #三立新聞 。
# 10236                              中正婦工健康講座，謝謝秀玲、玉惠、志雄和淑媛！
# 10237                                                  NaN
# 10238    🌟108大學多元選才與高中適性入學升學輔導講座直播網址➕相關資料🌟\n\n由臺北市高中學生家...
# 10239    #教育大小事奕華貼心提醒同學和家長📣\n\n🌟高一新生和家長照過來，108新舊課綱銜接課程🌟...
# 10240    【彥秀直白說】\n\n撕裂社會、導致世代對立的年金改革，在大法官釋憲後，就真的結束了嗎？退休...
# ...

# %% [markdown]
# 取出高嘉瑜和李彥秀文章中留言數>500的總讚數，並且畫成bar chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False
sns.set(font=['sans-serif'])
sns.set_style("whitegrid",{"font.sans-serif":['SimHei']})

# %%
import pandas as pd
df3 = pd.read_csv("C:/Users/Summer/Desktop/x/Taipei.csv")

# %%
df3
# Out:
#                       Date       Page_Name           Page_ID  Link    Type  \
# 0      2020/01/11 23:48:08        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 1      2020/01/12 14:28:57        壯闊台灣 吳怡農  1604793293120494   NaN   video
# 2      2019/08/01 13:43:51  林昶佐 Freddy Lim   365320250345879   NaN   photo
# 3      2020/01/17 20:51:35        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 4      2020/01/11 20:57:56             高嘉瑜      202188887719   NaN   photo
# ...                    ...             ...               ...   ...     ...
# 10238  2019/03/03 11:47:11         立法委員林奕華      209010448523   NaN    link
# 10239  2019/08/12 18:04:21         立法委員林奕華      209010448523   NaN   photo
# 10240  2019/08/24 16:10:18             李彥秀   606321216096498   NaN  status
# 10241  2019/12/18 11:25:11             賴士葆  1573873889493647   NaN   photo
# 10242  2019/12/31 03:47:38       費鴻泰（阿力克司）   893657620668012   NaN    link
#
# ...

# %%
comment = df3[(df3['Comment_Count'] > 500) & ((df3['Page_Name'] == '高嘉瑜') | (df3['Page_Name'] == '李彥秀'))].groupby(by ='Page_Name').count().reset_index().sort_values('All_Reaction_Count')

# %%
print(comment)
# Out:
#   Page_Name  Date  Page_ID  Link  Type  All_Reaction_Count  LIKE_COUNT  \
# 0       李彥秀    11       11     0    11                  11          11
# 1       高嘉瑜   134      134     0   134                 134         134
#
#    WOW_COUNT  LOVE_COUNT  HAHA_COUNT  SAD_COUNT  ANGRY_COUNT  Comment_Count  \
# 0         11          11          11         11           11             11
# 1        134         134         134        134          134            134
#
#    Share_Count  Message  Link_Title  Link Description  created_time
# 0           11       10           3                 0            11
# 1          134      131          31                 4           134

# %%
comment = comment.rename(columns={'All_Reaction_Count': '文章數'})

# %%
print(comment)
# Out:
#   Page_Name  Date  Page_ID  Link  Type  文章數  LIKE_COUNT  WOW_COUNT  \
# 0       李彥秀    11       11     0    11   11          11         11
# 1       高嘉瑜   134      134     0   134  134         134        134
#
#    LOVE_COUNT  HAHA_COUNT  SAD_COUNT  ANGRY_COUNT  Comment_Count  Share_Count  \
# 0          11          11         11           11             11           11
# 1         134         134        134          134            134          134
#
#    Message  Link_Title  Link Description  created_time
# 0       10           3                 0            11
# 1      131          31                 4           134

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']

comment.plot.bar(x='Page_Name', y='文章數')

# %% [markdown]
# 取出高嘉瑜與李彥秀的總發文數，並且畫成pie chart

# %%
import pandas as pd
df4 = pd.read_csv("C:/Users/Summer/Desktop/x/Taipei.csv")
df4
# Out:
#                       Date       Page_Name           Page_ID  Link    Type  \
# 0      2020/01/11 23:48:08        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 1      2020/01/12 14:28:57        壯闊台灣 吳怡農  1604793293120494   NaN   video
# 2      2019/08/01 13:43:51  林昶佐 Freddy Lim   365320250345879   NaN   photo
# 3      2020/01/17 20:51:35        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 4      2020/01/11 20:57:56             高嘉瑜      202188887719   NaN   photo
# ...                    ...             ...               ...   ...     ...
# 10238  2019/03/03 11:47:11         立法委員林奕華      209010448523   NaN    link
# 10239  2019/08/12 18:04:21         立法委員林奕華      209010448523   NaN   photo
# 10240  2019/08/24 16:10:18             李彥秀   606321216096498   NaN  status
# 10241  2019/12/18 11:25:11             賴士葆  1573873889493647   NaN   photo
# 10242  2019/12/31 03:47:38       費鴻泰（阿力克司）   893657620668012   NaN    link
#
# ...

# %%
df4.groupby("Page_Name")

# %%
fish = df4.groupby('Page_Name').get_group('高嘉瑜')

# %%
lee = df4.groupby('Page_Name').get_group('李彥秀')

# %%
fish['Date'].count()
# Out:
# 886

# %%
lee['Date'].count()
# Out:
# 598

# %%
total = df4[(df4['Page_Name'] == '高嘉瑜') | (df4['Page_Name'] == '李彥秀')].groupby(by ='Page_Name').count().reset_index().sort_values('All_Reaction_Count')
total
# Out:
#   Page_Name  Date  Page_ID  Link  Type  All_Reaction_Count  LIKE_COUNT  \
# 0       李彥秀   598      598     0   598                 598         598
# 1       高嘉瑜   886      886     0   886                 886         886
#
#    WOW_COUNT  LOVE_COUNT  HAHA_COUNT  SAD_COUNT  ANGRY_COUNT  Comment_Count  \
# 0        598         598         598        598          598            598
# 1        886         886         886        886          886            886
#
#    Share_Count  Message  Link_Title  Link Description  created_time
# 0          598      585         328                63           598
# 1          886      869         476                80           886

# %%
plt.pie(total['All_Reaction_Count'] , labels = total['Page_Name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x164f5076788>,
# ...
#  [Text(0.3301594396685566, 1.0492829667910104, '李彥秀'),
#   Text(-0.3301594396685567, -1.0492829667910104, '高嘉瑜')])

# %% [markdown]
# 請問高嘉瑜的按讚數和留言數有相似的趨勢嗎？

# %%
df_fish = df4[(df4["Page_Name"] == "高嘉瑜" )]

# %%
df_fish.plot(x='Date',y=['LIKE_COUNT','Comment_Count'])

# %%
plt.figure(figsize=(15,4)) #設定圖表大小

plt.title("number of like") # 加標題
plt.xlabel("Post Time")     # 加x軸標題
plt.ylabel("number")        # 加y軸標題   

#可以用疊加的方式，把想要的變數畫上去
plt.plot(df_fish['Date'],df_fish['LIKE_COUNT'])
plt.plot(df_fish['Date'],df_fish['Comment_Count'])
plt.plot(df_fish['Date'],df_fish['All_Reaction_Count'])

# %% [markdown]
# 請畫出高嘉瑜每天的發文折線圖

# %%
df_post_fish = df_fish.groupby(['Date'])['LIKE_COUNT'].count().reset_index(name='count')

# %%
df_post_fish
# Out:
#                     Date  count
# 0    2019/01/01 11:01:42      1
# 1    2019/01/04 13:21:26      1
# 2    2019/01/04 17:44:39      1
# 3    2019/01/05 16:17:45      1
# 4    2019/01/05 18:45:54      1
# ..                   ...    ...
# 881  2020/01/29 15:07:14      1
# 882  2020/01/30 19:11:31      1
# 883  2020/01/30 22:43:23      1
# 884  2020/01/31 10:47:31      1
# 885  2020/01/31 21:27:11      1
#
# [886 rows x 2 columns]

# %%
import matplotlib.ticker as ticker

plt.figure(figsize=(15,4)) #設定圖表大小

plt.title("Post Date") # 加標題
plt.xlabel("Time")          # 加x軸標題
plt.ylabel("Number of Post")        # 加y軸標題   

plt.plot(df_post_fish['Date'],df_post_fish['count'])
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(150)) #調整x軸要顯示幾個值
plt.show()

# %% [markdown]
# 請問總體來看，最熱門的發文時段是哪時候？

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Week'] = df['Date'].dt.strftime('%A')
df
# Out:
#                      Date       Page_Name           Page_ID  Link    Type  \
# 0     2020-01-11 23:48:08        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 1     2020-01-12 14:28:57        壯闊台灣 吳怡農  1604793293120494   NaN   video
# 2     2019-08-01 13:43:51  林昶佐 Freddy Lim   365320250345879   NaN   photo
# 3     2020-01-17 20:51:35        壯闊台灣 吳怡農  1604793293120494   NaN   photo
# 4     2020-01-11 20:57:56             高嘉瑜      202188887719   NaN   photo
# ...                   ...             ...               ...   ...     ...
# 10238 2019-03-03 11:47:11         立法委員林奕華      209010448523   NaN    link
# 10239 2019-08-12 18:04:21         立法委員林奕華      209010448523   NaN   photo
# 10240 2019-08-24 16:10:18             李彥秀   606321216096498   NaN  status
# 10241 2019-12-18 11:25:11             賴士葆  1573873889493647   NaN   photo
# 10242 2019-12-31 03:47:38       費鴻泰（阿力克司）   893657620668012   NaN    link
#
#        All_Reaction_Count  LIKE_COUNT  WOW_COUNT  LOVE_COUNT  HAHA_COUNT  ...  \
# ...

# %%
df_fish1 = df[df['Page_Name']=='高嘉瑜']

#算每星期每小時發了幾篇
df_fish1_post = df_fish1.groupby(['Week','Hour'])['LIKE_COUNT'].count().reset_index(name='count')

df_fish1_post
# Out:
#           Week Hour  count
# 0       Friday   06      1
# 1       Friday   07      7
# 2       Friday   08      3
# 3       Friday   09      7
# 4       Friday   10      5
# ..         ...  ...    ...
# 124  Wednesday   19      8
# 125  Wednesday   20      9
# 126  Wednesday   21     12
# 127  Wednesday   22      8
# 128  Wednesday   23      6
#
# [129 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

flights = df_fish1_post.pivot("Week", "Hour", "count")
# 畫出x-y-z的圖，比如 年-月-銷量 的熱圖
f, ax = plt.subplots(figsize=(9, 6))
#使用不同的顏色
sns.heatmap(flights, fmt="d",cmap='YlGnBu', ax=ax)
#設置座標字體方向
label_y = ax.get_yticklabels()
plt.setp(label_y, rotation=360, horizontalalignment='right')
label_x = ax.get_xticklabels()
plt.setp(label_x, rotation=45, horizontalalignment='right')
plt.show()
